# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from gensim.models import KeyedVectors
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model, Sequential
from keras.layers import Dense, Embedding, Input, LSTM, Dropout
from keras.layers import LSTM, Input, Bidirectional

# %% [markdown]
# # Supporting Functions

# %%
def print_distribution(df, labels_column_name):
    n = df.shape[0]
    print("{} labels frequency:".format(labels_column_name))
    print("Value\tCount\tPercent")
    indeces = df[labels_column_name].value_counts().index.tolist()
    counts = df[labels_column_name].value_counts().tolist()
    for val, count in zip(indeces, counts):
        print("{}\t{}\t{}%".format(val, count, (count / float(n)) * 100))
    
def get_max_words(text_arr):
    max_words = 0
    for line in text_arr:
        num_words = len(str(line).split())
        if num_words > max_words:
            max_words = num_words
    return max_words

# %% [markdown]
# # Load data

# %%
# Load in the csv data
#headlines_df = pd.read_csv("../data/headlines/labeled_headlines.csv", index_col=0, parse_dates=[0])
tweets_df = pd.read_csv('C:\\Users\\ericr\\Google Drive\\schoolwork\\current classes\\CS 230\\Project\\230_crypto\\data\\twitter\\hourly\\labeled_tweets_hourly.csv', encoding='ISO-8859-1')

print("There are {} tweets".format(tweets_df.shape[0]))
tweets_df.head()
# Out:
# There are 14422 tweets
#           Timestamp                                               Text  \
# 0  2017-01-02 00:00  Did anyone notice Bitcoin hit $1000 a few hour...
# 1  2017-01-02 00:00  Bitcoin Price Tops $1,000 in First Day of 2017...
# 2  2017-01-02 00:00  The latest Bitcoin Price Index is 997.75 USD h...
# 3  2017-01-02 00:00  Bitcoinã3å¹´ã¶ãã®1000ãã«ã«åãã£ã...
# 4  2017-01-02 00:00  #Bitcoin predictions from #WebBot @clif_high h...
#
#     1_hr_PC  2_hr_PC   6_hr_PC  12_hr_PC  24_hr_PC
# 0  0.224013  0.65496  1.423434  2.964399  2.537469
# 1  0.224013  0.65496  1.423434  2.964399  2.537469
# 2  0.224013  0.65496  1.423434  2.964399  2.537469
# 3  0.224013  0.65496  1.423434  2.964399  2.537469
# 4  0.224013  0.65496  1.423434  2.964399  2.537469

# %%
train_size = 11538 #use 80% of data for training

train_df = tweets_df[:train_size].copy()
test_df = tweets_df[train_size:].copy()

# %%
test_df.head()
# Out:
#               Timestamp                                               Text  \
# 11538  2017-12-04 00:00                #Bitcoin pic.twitter.com/xtLVNQVzgB
# 11539  2017-12-04 00:00  Had solar installed to offset our hot water po...
# 11540  2017-12-04 00:00  â Treasury crackdown on Bitcoin over concern...
# 11541  2017-12-04 00:00  â This Bitcoin collection is worth $75 milli...
# 11542  2017-12-04 00:00  ICO LENDING PLATFORMS ARE HOTT! Sign up and re...
#
#        1_hr_PC   2_hr_PC  6_hr_PC  12_hr_PC  24_hr_PC
# 11538  1.07912 -0.220256  1.07038 -0.735627  2.645715
# 11539  1.07912 -0.220256  1.07038 -0.735627  2.645715
# 11540  1.07912 -0.220256  1.07038 -0.735627  2.645715
# 11541  1.07912 -0.220256  1.07038 -0.735627  2.645715
# 11542  1.07912 -0.220256  1.07038 -0.735627  2.645715

# %% [markdown]
# # Data setup

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams['figure.figsize'] = (18,10)

# Label and title columns in datasets
BTC_LABEL_COL = '1_hr_PC'
TEXT_COL = 'Text'

# Determine max post length
max_words_train = get_max_words(train_df[TEXT_COL].values)
max_words_test = get_max_words(test_df[TEXT_COL].values)
max_words = max(max_words_train, max_words_test)
print("Max number of words in a post: {}".format(max_words))

# Plot distributions of labels
sns.set_style("whitegrid")
sns.distplot(train_df[BTC_LABEL_COL].values, label='Train')
sns.distplot(test_df[BTC_LABEL_COL].values, label='Test')
plt.legend()
# Out:
# Max number of words in a post: 82

# %%
# Split into x_train and y_train
print('\nGetting x_train, y_train, x_test, and y_test...')
(x_train, y_train_btc) = train_df[TEXT_COL].values, train_df[BTC_LABEL_COL]
(x_test, y_test_btc) = test_df[TEXT_COL].values, test_df[BTC_LABEL_COL]

# Print info about train and test
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
print("----------------------------")
# Out:
# Getting x_train, y_train, x_test, and y_test...
# 11538 train sequences
# 2884 test sequences
# ----------------------------

# %% [markdown]
# # Model setup (part 1/3)

# %%
test1 = np.asarray([str(x) for x in x_train])
test2 = np.asarray([str(x) for x in x_test])

# Set hyperparameters
max_features = 200000 # Num words in our vocabulary 
maxlen = max_words  # cut texts after this number of words
batch_size = 32  # Mini-batch size
epochs = 10 

# Train tokenizer to create a vocabulary of words
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(test1)

# Vectorize each headline
train_sequences = tokenizer.texts_to_sequences(test1)
test_sequences = tokenizer.texts_to_sequences(test2)

# Update x_train and x_test to be 'sequences' of data
print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(train_sequences, maxlen=maxlen)
x_test = sequence.pad_sequences(test_sequences, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Pad sequences (samples x time)
# x_train shape: (11538, 82)
# x_test shape: (2884, 82)

# %% [markdown]
# # Model setup (part 2/3)

# %%
# Build embedding layer using word2vec
EMBEDDING_FILE = "C:\\Users\\ericr\\Documents\\GoogleNews-vectors-negative300.bin\\GoogleNews-vectors-negative300.bin"
EMBEDDING_DIM = 300
word2vec = KeyedVectors.load_word2vec_format(EMBEDDING_FILE, binary=True)

word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))+1

embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
for word, i in word_index.items():
    if word in word2vec.vocab:
        embedding_matrix[i] = word2vec.word_vec(word)
        
embedding_layer = Embedding(nb_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=maxlen,
                            trainable=False)

# %% [markdown]
# # Model setup (part 3/3)

# %%
# Get the actual embeddings
sequence_input = Input(shape=(maxlen,), dtype='int32')
embeddings = embedding_layer(sequence_input)

# Construct the model
X = Bidirectional(LSTM(128, return_sequences=False))(embeddings)
X = Dense(1)(X)

# %% [markdown]
# # BTC Model

# %%
# Define the BTC model
model = Model(inputs=sequence_input, 
                  outputs=X)

# Compile the BTC model
model.summary()
model.compile(loss='mean_squared_error', 
                    optimizer='adam', 
                    metrics=['accuracy'])

# Select BTC labels for y
y_train = y_train_btc
y_test = y_test_btc
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 82)                0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 82, 300)           9924300
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 256)               439296
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 10,363,853
# Trainable params: 439,553
# Non-trainable params: 9,924,300
# _________________________________________________________________

# %%
# Run the BTC model
model.fit(x_train, 
          y_train, 
          batch_size=batch_size, 
          epochs=epochs, 
          validation_data=(x_test, y_test))
# Out:
# Train on 11538 samples, validate on 2884 samples
# Epoch 1/10
# 11538/11538 [==============================] - 141s 12ms/step - loss: 0.7401 - acc: 0.0000e+00 - val_loss: 2.6329 - val_acc: 0.0000e+00
# Epoch 2/10
# 11538/11538 [==============================] - 150s 13ms/step - loss: 0.7304 - acc: 0.0000e+00 - val_loss: 2.6740 - val_acc: 0.0000e+00
# Epoch 3/10
# 11538/11538 [==============================] - 155s 13ms/step - loss: 0.7213 - acc: 0.0000e+00 - val_loss: 2.6607 - val_acc: 0.0000e+00
# Epoch 4/10
# 11538/11538 [==============================] - 139s 12ms/step - loss: 0.7084 - acc: 0.0000e+00 - val_loss: 2.6913 - val_acc: 0.0000e+00
# Epoch 5/10
# 11538/11538 [==============================] - 145s 13ms/step - loss: 0.6853 - acc: 0.0000e+00 - val_loss: 2.6948 - val_acc: 0.0000e+00
# Epoch 6/10
# 11538/11538 [==============================] - 148s 13ms/step - loss: 0.6506 - acc: 0.0000e+00 - val_loss: 2.7107 - val_acc: 0.0000e+00
# Epoch 7/10
# 11538/11538 [==============================] - 144s 13ms/step - loss: 0.6065 - acc: 0.0000e+00 - val_loss: 2.7318 - val_acc: 0.0000e+00
# Epoch 8/10
# 11538/11538 [==============================] - 144s 12ms/step - loss: 0.5557 - acc: 0.0000e+00 - val_loss: 2.7829 - val_acc: 0.0000e+00
# Epoch 9/10
# 11538/11538 [==============================] - 142s 12ms/step - loss: 0.5058 - acc: 0.0000e+00 - val_loss: 2.8136 - val_acc: 0.0000e+00
# Epoch 10/10
# 11538/11538 [==============================] - 133s 12ms/step - loss: 0.4545 - acc: 0.0000e+00 - val_loss: 2.8183 - val_acc: 0.0000e+00

# %%
score, acc = model.evaluate(x_test, 
                            y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 2884/2884 [==============================] - 11s 4ms/step
# Test score: 2.81828870047
# Test accuracy: 0.0

# %% [markdown]
# # Evaluate the results
#     - Look at the distribution of the predicted results to see if the model makes large predictions
#     - Perform some error analysis

# %%
predictions = model.predict(x_test)

# %%
pred_series = pd.Series(np.squeeze(predictions))
pred_series.describe()
# Out:
# count    2884.000000
# mean        0.120921
# std         0.462608
# min        -1.842745
# 25%        -0.118820
# 50%         0.109992
# 75%         0.341697
# max         3.034098
# dtype: float64

# %% [markdown]
# ### First, print out text with corresponding percent changes greater than the cutoff

# %%
##### Set cutoff
cutoff = 2.0

test_text = list(test_df[TEXT_COL].values)
preds_list = list(np.squeeze(predictions))
labels_list = list(y_test)
count = 0

for i, label in enumerate(labels_list):
    if abs(label) >= cutoff:
        print('------------------')
        print('Text:\n {}'.format(test_text[i]))
        print('\tActual:  {}'.format(labels_list[i]))
        count += 1
        
print("----------------------")
print("Count of examples greater than cutoff: {}".format(count))
# Out:
# ------------------
# Text:
#  Still kicking myself for not buying #bitcoin at $200. Which is why I'm doing my happy dance after buying #litecoin this week under $100. #BTC #LTC
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Bitcoin is going crash hella hard in 2018 calling it now
# 	Actual:  -2.700979629
# ------------------
# Text:
#  With bitcoin futures set to trade, here's how it's going to work http:// a.msn.com/00/en-us/BBGpe cr?ocid=st â¦
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Cramer Remix: Bitcoin is the least transparent bubble Iâve ever seen http:// cnb.cx/2BXQBRI
# 	Actual:  -2.700979629
# ------------------
# Text:
#  If Lil Pump bought Bit Coin instead of a new chain. Those 3 racks would be worth 9 racks right now.
# 	Actual:  -2.700979629
# ------------------
# Text:
#  bitcoin mining is going to hit its cap in like 2 years and i don't know enough about economics to tell if that means it'll crash or skyrocket
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Cramer Remix: Bitcoin is the least transparent bubble Iâve ever seen http:// cnb.cx/2AGjt0v
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Bitcoin is too complicated for 140 characters
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Existem comercios nos EUA especificamente em New Hampshire que sÃ³ aceitam Bitcoin como moeda. Fiquem de olho, serÃ¡ o futuro
# 	Actual:  -2.700979629
# ------------------
# Text:
#  What happened to the price of Bitcoin ? The truth behind big bubbles and crashes http:// theconversation.com/what-happened- to-the-price-of-bitcoin-the-truth-behind-big-bubbles-and-crashes-88688?utm_source=twitter&utm_medium=twitterbutton â¦ via @ConversationEDU
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Interest over time ( #bitcoin ): pic.twitter.com/q5ej200veO
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Man if I had a Bitcoin for every time I accidentally fell asleep...
# 	Actual:  -2.700979629
# ------------------
# Text:
#  #LTC New Trading Opportunity Buy: Above 100 Partial Profit Target: 112 Main Profit target: 119 Stop-loss: 88 (near support level ) #BTC #Bitcoin #Litecoin $ BTC pic.twitter.com/gRtuprcCmA
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Wow... #electroneum #etn rally with #bitcoin #btc good for start after #nicehash disaster ...yeaaah #cryptocurrency #cryptopia #Bittrex #Poloniex #cryptonite pic.twitter.com/5GpCFHeO8r
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Swedish Bitcoin Exchange-Traded Fund Bigger Than 80% of US ETFs http:// dlvr.it/Q53Sf3 pic.twitter.com/OICyGGdzPl
# 	Actual:  -2.700979629
# ------------------
# Text:
#  The moment someone compares bitcoin to tulips, instantly demonstrates fundamental ignorance of the basic technology, it's decentralization, it's nature as sound money, and it's security properties. After 8 years, bitcoin itself, in cold storage, has never been seized. Seriously.
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Bitcoin : 'I'm part of a crazy wave' https:// lnkd.in/gwQefZb
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Bought over 50K bitcoin in 2006 for $1.92 each. I will randomly pick 25 people who retweet this and give one to each of you. Merry Christmas. #Bitcoin
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Join the BalehuBucks ICO #bounty program! View program details and learn how to register here: http:// bit.ly/2iZEKyb #cryptorewards #bitcoin #ICO #preico #crypto #balehubucks pic.twitter.com/zcr1ei8JBi
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Sundayâs are for ...but this Sunday itâs all about $ BTC ! #GDAXandChill #Bitcoin #Futures #CMEGroup #CBoe #HODL
# 	Actual:  -2.700979629
# ------------------
# Text:
#  one thing i dont get is why the margin requirement is that high ( alledgely at 28k usd ) if the #BTCUSD future contract is 5 bitcoin , nominal price will be around 80k usd, any one?
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Buy all of the Bitcoin https:// twitter.com/lukeeasterling /status/939270135105425409 â¦
# 	Actual:  -2.700979629
# ------------------
# Text:
#  $ NAV coin has very good potential #NAV #2018 #bitcoin #altcoin https:// blog.bestrate.org/nav-coin-why-i t-is-a-good-altcoin-to-invest-in-5dc07751c34c â¦
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Stepping in other people's bear traps violates the NAP, moron. I hope you have the bitcoin to pay your way out of this
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Dude. In 2013 bit coin cost $13.33 a single coin. Buying 100 coins would cost you $1,333, as of right now if you would sell those youâd get 1.6M. Thatâs fucking insane. Could of been a millionaire. Time machine anyone?
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Why is #Bitcoin So Important? http:// dld.bz/fmH6n #blockchain #cryptocurrency pic.twitter.com/9FbuVIcxNa
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Tried to explain Bitcoin to my mom. Now sheâs still confused and thinks it must be evil.
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Cryptocurrency Revolution COMPLETE FILM | Frank Giustra, Marco Streng Bitcoin Documentary https:// ceo.ca/@jonathanroth/ cryptocurrency-revolution â¦ https:// youtu.be/YwtEUD2crwA
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Fake Gunbot Bitcoin tool spreads Orcus RAT via spam https://www. scmagazine.com/orcus-rat-spre ad-via-spam-to-steal-bitcoin/article/713107/ â¦ #InfoSec #Malware
# 	Actual:  -2.700979629
# ------------------
# Text:
#  N Ã© querer falar mal do bitcoin ou q Ã© uma bolha nem nd disso. A moeda sÃ³ serve como um âinvestimentoâ por hr, enqnto estÃ¡ em alta. Mas qndo as pessoas finalmente comeÃ§arem a usar isso como moeda e n sÃ³ de forma especulativa o valor dela deve descer e mt, comparando com agr.
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Interesting fact: paper money doesn't burn, until its over 2X as hot as the temperature that would ruin a bitcoin flash drive" wallet (about 100 degres Celsius). So, technically, paper money is a harder asset"
# 	Actual:  -2.700979629
# ------------------
# Text:
#  The Beatles are the Bitcoin of music and Drake is etherum
# 	Actual:  -2.700979629
# ------------------
# Text:
#  Payment from @DailyFreeBits #bitcoin #faucet about 1431 satoshi from 07.12.2017 https:// dailyfreebits.com/?id=46770574 pic.twitter.com/ZYTT7HoNk6
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Itâs A Wonderful Life for #Bitcoin Evangelist as Community Expresses Its Gratitude https:// bitcoinmagazine.com/articles/its-w onderful-life-bitcoin-evangelist-community-expresses-its-gratitude/ â¦
# 	Actual:  -3.258135798
# ------------------
# Text:
#  You can now let a prospective buyer know that you accept Bitcoin on Craigstlist https://www. theverge.com/2017/12/9/1675 6842/craigslist-accept-cryptocurrency-bitcoin â¦ #Cryptopayments
# 	Actual:  -3.258135798
# ------------------
# Text:
#  #Bitcoin #BTC #Solar https:// thesunexchange.com /
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Dstou imaginanu essa mina ai q Ã© mais especulado q o bitcoin .. Seria ela a BitchCoin?
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Bienvenidos al boom de bitcoin , la primera burbuja financiera de la posverdad" https://www. elindependiente.com/economia/2017/ 12/09/el-populismo-alimenta-el-record-de-bitcoin â¦ Por Marta @GarciaAller"
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Terlalu lelah membahas bitcoin sama mastah tadi malem
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Bitcoin - damn missed that one
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Hey @Sonya_Lamb , bitcoin explained! https:// twitter.com/forbes/status/ 939638544179527680 â¦
# 	Actual:  -3.258135798
# ------------------
# Text:
#  10 dÃ¶nÃ¼m bitcoin aldÄ±m otoyol geÃ§mesini bekliyorum
# 	Actual:  -3.258135798
# ------------------
# Text:
#  The real benefit of bitcoin is miners pulling off computing capacity from the NSA.
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Bitcoin Has A Whale" Problem: 1,000 Investors Control Nearly Half The Market http://www.zerohedge.com:80/news/2017-12-08/bitcoin-has-whale-problem-1000-investors-control-nearly-half-market zerohedge.com/news/2017-12-0 â¦"
# 	Actual:  -3.258135798
# ------------------
# Text:
#  New post (CBOE bitcoin futures: How will they work and can I invest with them?) has been published on Press News - http://www. pressnewss.com/cboe-bitcoin-f utures-how-will-they-work-and-can-i-invest-with-them/ â¦ pic.twitter.com/YgWznaa9VS
# 	Actual:  -3.258135798
# ------------------
# Text:
#  When everything gets confiscated this world will be over. Bullets, food and water will take precedent over any form of money. Electricity and bitcoin will no longer exist. Fiat will be used to start fires.
# 	Actual:  -3.258135798
# ------------------
# Text:
#  #Cibercrimen #Blockchain #Bitcoin #Titanium la herramienta destinada a investigar, desarrollar y validar tÃ©cnicas y soluciones para que las fuerzas del orden investiguen actividades criminales o terroristas ligadas a #criptodivisas y #DeepWeb http:// bit.ly/T0n1AwE pic.twitter.com/ZYpGcsg3aI
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Why bitcoin âs price isÂ so high http:// tcrn.ch/2AH7Are
# 	Actual:  -3.258135798
# ------------------
# Text:
#  New concept: âcloutcoinâ like bitcoin but of course a whole lot better
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Looks like a Bitcoin market price chart lol
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Bitcoin vs. las burbujas mÃ¡s grandes de la historia: nunca terminan bien http:// cnn.it/2Bl15NZ pic.twitter.com/VoGXtQJXJi
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Today's Paper-Clips : Staple News" is out https:// paper.li/Sanjay_Uppal/1 341154749?edition_id=ebb51960-dd3c-11e7-872d-0cc47a0d1605 â¦ #bitcoin"
# 	Actual:  -3.258135798
# ------------------
# Text:
#  So is the whole Internet and bad comms lines, poorly written protocols, transportation, heating, AC etc. etc. These can all improve or be replaced including bitcoin I suppose. The answer is to upgrade, evolve and improve though if the underlying service/product is worth having.
# 	Actual:  -3.258135798
# ------------------
# Text:
#  #blockchain #Bitcoin #substratum https:// twitter.com/SubstratumNet/ status/939601054450307073 â¦
# 	Actual:  -3.258135798
# ------------------
# Text:
#  My grandfather worked for 50 years in the bitcoin mines and he never complained once.
# 	Actual:  -3.258135798
# ------------------
# Text:
#  #bitcoin uses more energy than Denmark! That's a lot of mining going on. #cryptocurrency #blockchain #investor #investment #invest #ethereum #xrp #ripple https:// arstechnica.com/tech-policy/20 17/12/bitcoins-insane-energy-consumption-explained/ â¦
# 	Actual:  -3.258135798
# ------------------
# Text:
#  So many questions about Bitcoin ..
# 	Actual:  -3.258135798
# ------------------
# Text:
#  I'd like to say you're welcome but we both know this has been worse for my health than shorting Bitcoin . You still da best though.
# 	Actual:  -3.258135798
# ------------------
# Text:
#  This Bitcoin extravaganza seems shady as fuck
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Gold 1979 to 1982 vs #Bitcoin :- $ GLD pic.twitter.com/v1jKL4pQ2u
# 	Actual:  -3.258135798
# ------------------
# Text:
#  beware of #FakeBitcoin #BCash #BitcoinCash $ BCH scam trying to mislead people and steal their #Bitcoin
# 	Actual:  -3.258135798
# ------------------
# Text:
#  ~ wtf is a bitcoin ~
# 	Actual:  -3.258135798
# ------------------
# Text:
#  â 4NEW TOKEN: AFTER MARKET PRICE SUPPORT AND LIQUIDITY http:// ift.tt/2jClT9l #bitcoin
# 	Actual:  -3.258135798
# ------------------
# Text:
#  New post ( Bitcoin : Is Market Already Cornered? 1000 People Own 40% Of All Bitcoins?) has been published on CONTI TONIGHT - https://www. contitonight.com/bitcoin-is-mar ket-already-cornered-1000-people-own-40-of-all-bitcoins/ â¦ pic.twitter.com/FgbxOklmIP
# 	Actual:  -3.258135798
# ------------------
# Text:
#  https://www. theverge.com/2017/12/9/1675 6842/craigslist-accept-cryptocurrency-bitcoin â¦ #Bitcoin is getting even more popular.
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Best time to be alive? Today! #bitcoin #cryptocurrency #thereum #cryptoconnection #litecoin #satoshi
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Iâm selling #bitcoin via paypal and can accommodate credit/debit cards. Message me if you would like to buy! #pic.twitter.com/RbfWhz7Uhb
# 	Actual:  -3.258135798
# ------------------
# Text:
#  one post about #BitcoinCash and I already got a bunch of #trolls following me... #CryptoCultureWars #mixedmessages just think about who is funding the all of the paid content supporting #Bitcoin
# 	Actual:  -3.258135798
# ------------------
# Text:
#  i think you're over-estimating how dedicated the newest adopters are. most getting into bitcoin now are probably just in search of easy profit
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Steam just replaced Bitcoin for LITECOIN because of the delays and fees. Great news for Litecoin pic.twitter.com/UCSBcz1rDS
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Wall Street Breakfast: Weekly Highlights https:// buff.ly/2BpG7xJ #bitcoin #cryptocurrency pic.twitter.com/qMejv6O1zu
# 	Actual:  -3.258135798
# ------------------
# Text:
#  #bitcoin Another spot on call to go in on bitcoin early this year. Check our messages. #markcubansucks
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Noob opinion: Bitcoin wonât be the winning crypto. Winner will support low cost/high volume transactions and be green.
# 	Actual:  -3.258135798
# ------------------
# Text:
#  #lol #bitcoin #joke pic.twitter.com/Ips9FxbEsc
# 	Actual:  -3.258135798
# ------------------
# Text:
#  We buying bitcoin now? Lit
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Bitcoin âs rise in 2017 has moved it into the investing mainstream and cultural spotlight https://www. wsj.com/articles/why-b itcoin-why-now-1512820800 â¦ via @WSJ
# 	Actual:  -3.258135798
# ------------------
# Text:
#  1PSrzcfdkeY1qnGxrNFF9YVKrLUc98JYGq -My Bitcoin Address :) Send me some Bitcoin If youâre feeling generous
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Come join the Bitcoin Cash Fund. There's lots of us working on different projects here https:// chat.thebitcoincash.fund/channel/general
# 	Actual:  -3.258135798
# ------------------
# Text:
#  Target reached we #infected #WallStreet with #bitcoin and now you will see how #WallStreet will be destroyed by $ BTC
# 	Actual:  3.77957368
# ------------------
# Text:
#  Top story: Twas The Night Before Bitcoin Futures https://www. forbes.com/sites/petertch ir/2017/12/10/twas-the-night-before-bitcoin-futures/ â¦ , see more http:// tweetedtimes.com/media/forbes/a ll?s=tnp â¦
# 	Actual:  3.77957368
# ------------------
# Text:
#  #Eventos Discusiones sobre blockchain en DC (parte II): Creo que el tÃ©rmino Bitcoin es simplemente mÃ¡s sexy" https://www. criptonoticias.com/eventos/discus iones-sobre-blockchain-en-dc-parte-ii-creo-que-el-termino-bitcoin-es-simplemente-mas-sexy/ â¦"
# 	Actual:  3.77957368
# ------------------
# Text:
#  If the $ CBOE website isn't working, for those who want to watch #bitcoin futures activity, look here: https://www. cnbc.com/quotes/?symbol =%40XBT.1 â¦ pic.twitter.com/MBNRFYDmPf
# 	Actual:  3.77957368
# ------------------
# Text:
#  Welcome to Bitcoin @CBOE https:// twitter.com/CBOE/status/94 0001581482815498 â¦
# 	Actual:  3.77957368
# ------------------
# Text:
#  Bitcoin Futures Trading Opens, Bringing Crypto to Wall Street https:// goo.gl/erzPNv
# 	Actual:  3.77957368
# ------------------
# Text:
#  Thinking of Shorting Bitcoin Futures? GBTC Bears Nurse Big Losses https:// news.bitcoin.com/thinking-of-sh orting-bitcoin-futures-gbtc-bears-nurse-big-losses/ â¦ via @BTCTN
# 	Actual:  3.77957368
# ------------------
# Text:
#  Not doing much in bitcoin pricing
# 	Actual:  3.77957368
# ------------------
# Text:
#  Real footage from the opening of @CBOE #bitcoin futures market. $ BTC just imagine when #dogecoin futures start. pic.twitter.com/j9pvkV0j5w
# 	Actual:  3.77957368
# ------------------
# Text:
#  Someone needs to explain bitcoin to me I don't get it
# 	Actual:  3.77957368
# ------------------
# Text:
#  RealTimeCrypto: Bitcoin Futures Launch Could Rekindle Push for ETF, CBOE Says http:// ift.tt/2kiyv51
# 	Actual:  3.77957368
# ------------------
# Text:
#  Register for The TokenPay Coin Sale - TokenPay is Bitcoin on Steroids! https://www.tokenpay.com?rc=0RQYN tokenpay.com/?rc=0RQYN
# 	Actual:  3.77957368
# ------------------
# Text:
#  Hoje, a grande discussÃ£o Ã© essa: as pessoas jÃ¡ deixaram de usar o bitcoin como moeda e, no momento, usam apenas para investimento. Ã esse o motivo que mais ameaÃ§a a moeda virtual: quando as pessoas decidirem parar de investir na moeda, ela vai perder o valor e se desintegrar.
# 	Actual:  3.77957368
# ------------------
# Text:
#  Bitcoin Looks Remarkably Like A Bubble, New Zealand's Central Banker Warns http:// bit.ly/2kPnZpC pic.twitter.com/PNxL9vDSck
# 	Actual:  3.77957368
# ------------------
# Text:
#  I know people talking shit about @Bitcoin who own neither Bitcoin nor dollars.
# 	Actual:  3.77957368
# ------------------
# Text:
#  El bitcoin debuta en el mercado mundial a 15.000 dÃ³lares la unidad #AFP http:// u.afp.com/4yPr
# 	Actual:  3.77957368
# ------------------
# Text:
#  a petty detail. Metamorphologically you're more American than Ronald Reagan. Don't disturb me with petty details when I'm on the war-path. P.S. I am still stunned at beating you to the draw on BitCoin . :-p
# 	Actual:  3.77957368
# ------------------
# Text:
#  IG suger pÃ¥ Bitcoin . 1. StÃ¤ngt vid stora kursrÃ¶relser, 2. StÃ¶rst spread, 3. Extrem skatteeffekt
# 	Actual:  3.77957368
# ------------------
# Text:
#  #Bitcoin http://www. businessinsider.com/bitcoin-future s-sends-price-up-2017-12 â¦
# 	Actual:  3.77957368
# ------------------
# Text:
#  Thinking of Shorting Bitcoin Futures? GBTC Bears Nurse Big Losses https:// reviewcoin.me/blog-new/think ing-of-shorting-bitcoin-futures-gbtc-bears-nurse-big-losses/ â¦ pic.twitter.com/YOwyuqSVVy
# 	Actual:  3.77957368
# ------------------
# Text:
#  Le bitcoin fait ses dÃ©buts sur une bourse mondiale au prix de 15.000 dollars l'unitÃ© #romandie .com - ActualitÃ©s #F https://www. dukascopy.com/refpro/in.php? aHR0cHM6Ly93d3cuZHVrYXNjb3B5LmNvbS9meHNwaWRlci9mci81MTI5NTAwMDUwOTIyNDg3MzYxLz91dG1fc291cmNlPXR3aXR0ZXImdXRtX21lZGl1bT1zb2NpYWwmdXRtX2NhbXBhaWduPWZ4c3BpZGVyJTIwdHdpdHRlciUyMHBvc3RpbmcKc3BwLXR3LVNwaWRGUg== â¦
# 	Actual:  3.77957368
# ------------------
# Text:
#  Bitcoin makes debut on major stock exchange at US$15,000 per unit https:// cna.asia/2kPR1FG pic.twitter.com/RmoJeETbOo
# 	Actual:  3.77957368
# ------------------
# Text:
#  The problem is that Bitcoin could go to Q in a matter of days. Most companies have some assets.
# 	Actual:  3.77957368
# ------------------
# Text:
#  Just one of the many expensive artworks hanging in my household, all thanks to my previous investments in Bitcoin pic.twitter.com/7JyzxERXMs
# 	Actual:  3.77957368
# ------------------
# Text:
#  Blockchain and the proof of work backs bitcoin , which is more that you can say for FIAT...
# 	Actual:  3.77957368
# ------------------
# Text:
#  A boy asked his bitcoin -investing dad for 1 #Bitcoin for his birthday. Dad: What? $15,554??? $14,354 is a lot of money! What do you need 16,872 for anyway?
# 	Actual:  3.77957368
# ------------------
# Text:
#   Bitcoin is always up, it's like the internet." @tonevays https:// twitter.com/TraceMayer/sta tus/940005435016384512 â¦"
# 	Actual:  3.77957368
# ------------------
# Text:
#  It begins. #bitcoinfutures #Bitcoin https:// twitter.com/cboe/status/94 0001581482815498 â¦
# 	Actual:  3.77957368
# ------------------
# Text:
#  Free Bitcoin - The bitcoin faucet where YOU decide when to claim! http:// moonbit.co.in/?ref=6300f67ea b78 â¦ #bitcoin #faucet
# 	Actual:  3.216965355
# ------------------
# Text:
#  For those asking were I got this Bitcoin orderd it from Wish app for couple bucks just oneâ¦ https://www. instagram.com/p/Bc0pp7zH4Zg/
# 	Actual:  3.216965355
# ------------------
# Text:
#  I used coinbase to purchase bitcoin then exchanged for ripple with gatehub wallet. Idk what kind of fees I took totally but got 5000 ripple for $1000 USD. Have almost tripled my money since I bought maybe a month ago. First ever long term investment!
# 	Actual:  3.216965355
# ------------------
# Text:
#  New(s: (video) Bitcoin Cash Rallies | Here's what you need to know http:// twib.in/l/GEKaLME9xRXE via @YouTube #Bitcoin #Cash
# 	Actual:  3.216965355
# ------------------
# Text:
#  #Bitcoin 's #illiquidity : As more people buy #bitcoin #transaction times get longer. Transaction fees are going higher, too. #ponzi #crash http://www. businessinsider.com/bitcoin-is-ill iquid-transaction-times-2017-12 â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  CME Bitcoin futures launched! - http:// cryptogeeks.com/cme-bitcoin-fu tures-launched â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  pray bitcoin hits 100k
# 	Actual:  3.216965355
# ------------------
# Text:
#  Fresh #takeaways from @grantcardone How I Made 1.6M Dollars with #Bitcoin https:// youtu.be/GM9C7MMZBpU via @YouTube
# 	Actual:  3.216965355
# ------------------
# Text:
#  #Bitcoin vuelve a marcar un mÃ¡ximo, pese al riesgo que nos dicen que hay. VÃ­a @zirigozacom https:// twitter.com/zirigozacom/st atus/942543743072329728 â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin fork! can I gain access to the coins https:// goo.gl/fb/DXz4Yz
# 	Actual:  3.216965355
# ------------------
# Text:
#  âFact is, bitcoin is a gift from God to help humanity sort out the mess it has made with its money,â #jesusfirst #bitcoin #decentralized @maxkeiser
# 	Actual:  3.216965355
# ------------------
# Text:
#  https:// medium.com/@nopara73/zero link-massive-scale-coinjoin-is-about-to-be-deployed-participate-in-the-final-test-and-earn-6225939d15fb â¦ #bitcoin
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin Futures Chart http:// d.quiktweet.com/688 #QuikTweets @CMEGroup @Options Available at http:// cmegroup.com/quikstrike - register for QuikStrike Essentials
# 	Actual:  3.216965355
# ------------------
# Text:
#  http://www. niemanlab.org/2017/12/coveri ng-bitcoin-while-owning-bitcoin/ â¦ the days of bitcoin stunt journalism are over. Today, if you write about bitcoin , you canât ethically own it, any more than you can own shares directly in companies you write about""
# 	Actual:  3.216965355
# ------------------
# Text:
#  [New Post] How do I accept bitcoin on Magento 1.9? http:// ift.tt/2COqE7s #magento
# 	Actual:  3.216965355
# ------------------
# Text:
#  4/ Weâve gone through a few iterations of boom/bust in #crypto , with the most recent coming in late 2013 when #bitcoin first crossed $1K, only to then lose > 80% of its value by Jan 2015.
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin ? Pffffffff.... Balkan! pic.twitter.com/QLU8FgD4JE
# 	Actual:  3.216965355
# ------------------
# Text:
#  Currency ka king Bitcoin ZEE Business News 16 Dec Jldi hi hoga India m legal http://www. youtube.com/watch?v=xUtGb4 -eOBU â¦ http:// americanstocktrader.com/currency-ka-ki ng-bitcoin-zee-business-news-16-dec-jldi-hi-hoga-india-m-legal/ â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin Leads to 'Revolution' in Commodity Trading http:// bit.ly/2B2Ybhi #blockchain
# 	Actual:  3.216965355
# ------------------
# Text:
#  http:// ift.tt/2kFhB0v Bitcoin Bubbles: A History #Bitcoin #Blockchain
# 	Actual:  3.216965355
# ------------------
# Text:
#  Mystery Founder Of Bitcoin : Uncovering Satoshi Nakamoto's Identity Of Bi... https:// youtu.be/Bze53qwHS8o via @YouTube
# 	Actual:  3.216965355
# ------------------
# Text:
#  South Africa Wants to Track and Tax Bitcoin Trading https:// news.bitcoin.com/south-africa-w ants-track-tax-bitcoin-trading/ â¦ via @BTCTN
# 	Actual:  3.216965355
# ------------------
# Text:
#  Â¿PodrÃ¡ llegar el bitcÃ³in a los 500 mil dÃ³lares en 2020? McAfee dice que sÃ­ #pronÃ³stico https:// goo.gl/FAEjB7
# 	Actual:  3.216965355
# ------------------
# Text:
#  CRYPTO EXCHANGE NEWS: Bitcoin futures begin trading on CME, price little changed http:// dlvr.it/Q6RGX8 â via https:// goo.gl/ifcBSF
# 	Actual:  3.216965355
# ------------------
# Text:
#  pocos recuerdan la caida de las .com a principios del 2000. Algo asi puede pasar con #bitcoin
# 	Actual:  3.216965355
# ------------------
# Text:
#  CRYPTO EXCHANGE NEWS: CME officially launches Bitcoin futures trading http:// dlvr.it/Q6RGWW â via https:// goo.gl/ifcBSF
# 	Actual:  3.216965355
# ------------------
# Text:
#  CRYPTO EXCHANGE NEWS: TradeStation to Support Trading of CME Group Bitcoin Futures on Launch http:// dlvr.it/Q6RGTg â via https:// goo.gl/ifcBSF
# 	Actual:  3.216965355
# ------------------
# Text:
#  New(s: (video) How Bitcoin Works in 5 Minutes (Technical) http:// twib.in/l/45e7jRpzerg7 via @YouTube . #Bitcoin #video
# 	Actual:  3.216965355
# ------------------
# Text:
#  My aunt can't stop talking about Bitcoin
# 	Actual:  3.216965355
# ------------------
# Text:
#  Congrats! Create an account on Binance and trade in minutes! No ID verification to sign up! Click here- https://www. binance.com/?ref=12708886 #bitcoin #btc #cryptocurrency #crypto #altcoins #xrp #trx #xvg #ada #eth #ltc https:// twitter.com/binance_2017/s tatus/942233211018424325 â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  Always nice when @Sophos stops your computer been hijacked to mine bitcoin , when your surfing the web on @opera #freeantivirus #cryptocurrency #bitcoin #ruiningtheinternet
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin Futures Open Above $20,000... Then Dump | Zero Hedge http://www. zerohedge.com/news/2017-12-1 7/bitcoin-futures-open-above-20000-then-dump â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  Un bitcoin sans hÃ©sitation. https:// twitter.com/barbabesque/st atus/942446406010376192 â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  Yes BECAUSE $ NEO went from less than 0.00028981 (?) to 0.00355718 a pop and at the same time $ BTC price went up If you had sold $ NEO back in mid-August for 47.58 USD (0.01141880 BTC at that time) worth of Bitcoin you'd have more than 600k right now
# 	Actual:  3.216965355
# ------------------
# Text:
#  ATFS Project is the worldâs first decentralized AgriTech & Food Science crowdfunding project built https://www. atfslab.io / #ATFS_LAB #atfs #atfsico #plantbasedmeat #agritech #foodrevolution #ico #crowdfunding #cryptocurrency #ethereum #erc20 #bitcoin #smartcontract #altcoin
# 	Actual:  3.216965355
# ------------------
# Text:
#  #bitcoin approaches $20K, but is the bubble about to burst? https:// finance.yahoo.com/news/bitcoin-a pproaches-20k-bubble-burst-234825029.html â¦ pic.twitter.com/CTbWF97MfA
# 	Actual:  3.216965355
# ------------------
# Text:
#  Free Dogecoin - The dogecoin faucet where YOU decide when to claim! http:// moondoge.co.in/?ref=ba306661e dae â¦ #dogecoin bitcoin
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin is almost 20000 pic.twitter.com/ThNs7rOeK8
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin Ã© o futuro
# 	Actual:  3.216965355
# ------------------
# Text:
#  If you've been thinking about getting some bitcoin or cryptocurrency the first step is to get an account on coinbase. Use my link and we both get $10 in free bitcoin once you spend over $100. https://www. coinbase.com/join/58c078c22 309060108c12c36?src=twitter â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  So futures in USD betting has started? Bitcoin is traded 24/7/365
# 	Actual:  3.216965355
# ------------------
# Text:
#  Gente que dice que el bitcoin es una burbuja para invertir ellos mismos... cabrones. #bitcoin #bitcoins
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin approaches $20K, but is the bubble about to burst? http:// ift.tt/2B1B4nd
# 	Actual:  3.216965355
# ------------------
# Text:
#  ICO News: (Bee Tokenâs AirBnB-esque Home Sharing ICO Date Set) -Read on BlockDiscover: http://www. blockdiscover.com/ico-news/bee-t okens-airbnb-esque-home-sharing-ico-date-set/ â¦ #ICO #Bitcoin #Blockchain @thebeetoken pic.twitter.com/XPT2W8qFK3
# 	Actual:  3.216965355
# ------------------
# Text:
#  ãéæã¡ã®æ¹ããã£ãããã¡ãã«ãã¾ã£ã¦ã Bitcoin æ¯ãè¾¼ãã§ããã¦ãããããã§ï¼ 3CYWcVqPJTng9EEdKpCwMmacpDzsHaxK2T
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin as store of value only, because it's scarce as gold" doesn't hold water. Scarcity was part of gold's exchange utility and exchange drove its value (regression theorem). If #Bitcoin will not be exchanged (because or fees), other cryptos will take over. #BitcoinCash"
# 	Actual:  3.216965355
# ------------------
# Text:
#  1 bitcoin vale mto mais que 10 mil reais
# 	Actual:  3.216965355
# ------------------
# Text:
#  On pace for about 220 contracts in first hour. The CBOE (CFE) bitcoin contract traded 570 in 1st hour. I guess that's about in line considering tick value for CME is 2.5 times that of CBOE.
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin futures begin trading on CME Bitcoin futures make their second debut on CME ------------------------------ #news #buzzvero #events #lastminute #reuters #cnn #abcnews #bbc #foxnews #localnews #nationalnews #worldnews #Ð½Ð¾Ð²Ð¾ÑÑÐ¸ #newspaper #noticias pic.twitter.com/tghQCdfcg4
# 	Actual:  3.216965355
# ------------------
# Text:
#  Just because I tweet about bitcoin doesnât mean that I do 100% support it. Bear in mind that the price is volatile and unpredictable, and it could be just a bubble. So invest at your own risk :)
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin approaches $20K, but is the bubble about to burst? http:// ift.tt/2B1B4nd
# 	Actual:  3.216965355
# ------------------
# Text:
#  If my bf brings up bitcoin & ripple one more time .....
# 	Actual:  3.216965355
# ------------------
# Text:
#  What happens when the volume goes up and the price goes down? #BTC #bitcoin
# 	Actual:  3.216965355
# ------------------
# Text:
#  Like follow and share! #bitcoin #btc #litecoin #ethereum #dash #cryptocurrency #crypto #ripple #iota #money pic.twitter.com/9xRVyD2FTM
# 	Actual:  3.216965355
# ------------------
# Text:
#  Bitcoin : Â¿Riesgo o futuro? http://www. expansion.com/mercados/divis as/2017/12/17/5a369d0ee5fdea310c8b4584.html â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  #Asia Regulators Mull Bitcoin Frenzy #investorseurope #technology http:// investorseurope.technology/p/4090964103/2 017/12/16/asia-regulators-mull-bitcoin-frenzy-investorseurope-technology?utm_medium=social&utm_source=twitter â¦
# 	Actual:  3.216965355
# ------------------
# Text:
#  Everyoneâs looking to get in on bitcoin these days â even ISIS. http:// bit.ly/2BdeAwo
# 	Actual:  3.216965355
# ------------------
# Text:
#  What it feels like to earn #bitcoin on a daily basis with http:// SlideCoin.co (Available on Google Play) #money #Android pic.twitter.com/qC0lHacFiP
# 	Actual:  -2.235422827
# ------------------
# Text:
#  7 #Cryptocurrencies to watch in 2018 if youâre on the hunt for the next #Bitcoin : #Crypto #Litecoin #Ripple #Monero #Neo #Cardano #Iota #BitcoinCash http:// on.mktw.net/2jSdGxG
# 	Actual:  -2.235422827
# ------------------
# Text:
#  How do cryptocurrencies help with corruption? (Serious question). As of today Bitcoin is only facilitating money laundering
# 	Actual:  -2.235422827
# ------------------
# Text:
#  How the Winklevoss Twins Found Vindication in a Bitcoin Fortune https://www. nytimes.com/2017/12/19/tec hnology/bitcoin-winklevoss-twins.html â¦ #Bitcoin #cryptocurrency #cryptonews #blockchain
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Bitcoin =MySpace while litecoin is Facebook..yawn https:// twitter.com/CNBCFastMoney/ status/942895113709211648 â¦
# 	Actual:  -2.235422827
# ------------------
# Text:
#  If you sell all your bitcoin in 2017 then all your exs boyfriends will die in 2018.
# 	Actual:  -2.235422827
# ------------------
# Text:
#  What it feels like to earn #bitcoin on a daily basis with http:// SlideCoin.co (Available on Google Play) #money #Android pic.twitter.com/DNqnUbZTtW
# 	Actual:  -2.235422827
# ------------------
# Text:
#  @LeoDuffOff OU EST TA VIDEO SUR LE BITCOIN
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Excellent work! I think this already a Bitcoin Cash meetup in Tokyo though. Check it out at https://www. meetup.com/Tokyo-Bitcoin- Cash-Meetup-Group/ â¦ . Become a member and take part.
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Bosch to Build $1.1 Billion Chip Plant for Self-Driving Cars ! last chance to buy #iota ! https://www. bloomberg.com/amp/news/artic les/2017-06-19/bosch-to-build-1-1-billion-chip-plant-for-self-driving-cars â¦ #bitcoin #ripple #ethereum #litecoin #cardano
# 	Actual:  -2.235422827
# ------------------
# Text:
#  I honestly thought that bitcoin was the currency for bitmojis for a solid two point five months
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Bill Gates in 2014: Bitcoin is 'better than currency' http:// bit.ly/2oOd3u1 http:// bbmp.io pic.twitter.com/JrTodVQ9Ml
# 	Actual:  -2.235422827
# ------------------
# Text:
#  I got my grandpa into bitcoin he wants to drop 10k
# 	Actual:  -2.235422827
# ------------------
# Text:
#  To anyone new in this space, this guy Roger Ver.... is the King of Propaganda and has his own agenda. #BCash #Bitcoin https:// twitter.com/Ali_Ha55an_/st atus/943220273079312385 â¦
# 	Actual:  -2.235422827
# ------------------
# Text:
#  When someone starts talking about their Bitcoin losses, then I'll really pay attention.
# 	Actual:  -2.235422827
# ------------------
# Text:
#  But Bitcoin causing global warming...
# 	Actual:  -2.235422827
# ------------------
# Text:
#  At the airport you have to declare 10.000â¬ But you can't declare bitcoin because you're just holding a private key Bitcoin has no physical location #THANKYOUANDREAS https:// youtu.be/EZh1-ZqffOw
# 	Actual:  -2.235422827
# ------------------
# Text:
#  It doesn't really mean much. I was a scalper for years though so I've logged thousands of eyeball-hours on 1m sticks. Bitcoin 1m has beautifully organic flow and legible sentiment compared to spammy traditional markets.
# 	Actual:  -2.235422827
# ------------------
# Text:
#  ya es tiempo de promocionar el bitcoin
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Trump admin gonna take credit for Bitcoin âs value too?
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Should we be buying gold or bitcoin at the mo JC?
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Bitcoin ã¨ãã®ä»®æ³éè²¨ã®å¤¢è¦ãã
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Got questions about #bitcoin or other #cryptocurrencies ? Come join the Crypto FAQ group on telegram. All are welcome! The goal is to provide a welcoming, open environment to discuss, learn, and share knowledge https:// t.me/crypto_faq
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Its still early into my #bitcoin experience but so far I like it. I am very #happy with my #cryptocurrency #portfolio from just starting with #bitcoins , I am now into #altcoins and #cloudmining . What an evolution in just one month!!!
# 	Actual:  -2.235422827
# ------------------
# Text:
#  #bitcoin how to buy #cardano #ripple + other alt coins using binance https://www. pscp.tv/w/bQhNmTFXZ0tn RG5WWE1PanZ8MVprS3pkVkxZakRKdvfUYm0MaTtN1BeLAS-idH9r6W4aXboYAvQkXnL6DKn3 â¦
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Not a Bubble" - Bitcoin and Markets - 12/19/2017 https:// youtu.be/FK8SV7N76D0 via @YouTube"
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Pay with bitcoin and get free biryani at this Chennai restaurant - The Hindu http:// ift.tt/2kLYrGi #Chennai
# 	Actual:  -2.235422827
# ------------------
# Text:
#  $17k Breached: #Bitcoin #Price Now Down 15% from All-Time High: Bitcoin 's price has dippedâ¦ https:// goo.gl/fb/5fwQzP
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Bitcoin : Â¿Por quÃ© invertir en la moneda del futuro? #money https:// goo.gl/aB2GHU?btz23=2 358121019 â¦
# 	Actual:  -2.235422827
# ------------------
# Text:
#  a quick flashback to last night where she earned a good amount stripping. Erm, I invested in bitcoin ? Details aren't important, let's just have some girly time~""
# 	Actual:  -2.235422827
# ------------------
# Text:
#  Deputados mais uma vez sem nada o que fazer. Mais uma vez atacando a tecnologia. Assine a petiÃ§Ã£o contra a criminalizaÃ§Ã£o do Bitcoin no Brasil. http:// chn.ge/2AZKMCl
# 	Actual:  -2.235422827
# ------------------
# Text:
#  bitcoin steak
# 	Actual:  -2.235422827
# ------------------
# Text:
#  At least it's not bitcoin
# 	Actual:  -2.235422827
# ------------------
# Text:
#  DOGE faster than Bitcoin and Litecoin. And is at .0075? Investors time to Load. Ripple hits a $1 Doge belongs at $10$$$
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Ripple is a knockoff of bitcoin . Iâve been studying all cryptos since day one. I am highly qualified. What is your qualification âtonyâ.
# 	Actual:  -3.130703337
# ------------------
# Text:
#  SAIBA TUDO SOBRE O BITCOIN .: http:// youtu.be/cX9VwjAQFG0?a via @YouTube
# 	Actual:  -3.130703337
# ------------------
# Text:
#  He's just mad that young people are making money instead of an old man like him. It's ok, keep talking trash about Bitcoin . We'll just be over here getting rich!
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Nouvelle toile en cours. DÃ©tail du pochoir btc #pboy #pascalboyart #acrylic #bitcoin #cryptocurrency #cryptoart #paris pic.twitter.com/trvu3QbeD0 pic.twitter.com/S0xbJJgmUh
# 	Actual:  -3.130703337
# ------------------
# Text:
#  OwlNest" Launched as the Worldâs First blockchain Hotel Management Service https:// bit-media.org/news/owlnest-l aunched-as-the-worlds-first-blockchain-hotel-management-service/ â¦ #blockchain #Bitcoin #coindesk #cointelegraph #crypto #cryptocurrency #eot"
# 	Actual:  -3.130703337
# ------------------
# Text:
#  These weed stocks are heating up nicely. I think we are getting ready to shift sector momentum unless bitcoin runs back to its highs. https:// twitter.com/otc_watch/stat us/942874606775418881 â¦
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Some of the  bitcoin " photos that are around. Ugh. pic.twitter.com/HmDdhXaV1G"
# 	Actual:  -3.130703337
# ------------------
# Text:
#  $ GS Goldman is setting up a #cryptocurrency trading desk https://www. bloomberg.com/news/articles/ 2017-12-21/goldman-is-said-to-be-building-a-cryptocurrency-trading-desk â¦ #bitcoin
# 	Actual:  -3.130703337
# ------------------
# Text:
#  $ BTC #bitcoin I see you Dont disappoint pic.twitter.com/6GoY654jjq
# 	Actual:  -3.130703337
# ------------------
# Text:
#  NEW EPISODE COMING TONIGHT! It's been a busy few weeks but we are back, talking about roles of government and a little bitcoin . Stay tuned, download/subscribe on iTunes or the google play store!
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Multiple Bidders Claim $16 Million Series B for Bitcoin Startup Coins
# 	Actual:  -3.130703337
# ------------------
# Text:
#  @DavisRamsey @mikehitch Iâm forced by the weight of evidence to admit the error of my ways. ***googles âhow to buy bitcoin â*** https:// twitter.com/stockcats/stat us/943880726033915909 â¦
# 	Actual:  -3.130703337
# ------------------
# Text:
#  $ BTC on a #SupportResistance level? https://www. albiontrader.com/single-post/20 17/12/22/BTC-on-a-SupportResistance-level â¦ $ BTCUSD #BTC #BitCoin #CryptoCurrency #Support #Resistance #TrendLine #AlbionTrader pic.twitter.com/pOqQBowNts
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Therein lies the rub. Satoshi would disagree. A peer to peer electronic âgoldâ system? Centralized second layers? Own the issues. Donât redefine them. #Bitcoin https:// twitter.com/jratcliff/stat us/943991781741551616 â¦
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Chirpified: Sekilas Nilai Tukar Bitcoin & Ilustrasi Yang Menghantui Pemiliknya" by @Ronnie_Rusli & @aditnamasaya http:// chirpstory.com/li/377591"
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Please donât preach, post, talk, teach bitcoin /crypto if you arenât even able to afford one single coin. So over all these people talking about crypto with their 200 dollars in their coinbase account.
# 	Actual:  -3.130703337
# ------------------
# Text:
#  @crysstrueheart the best info out there is @RichardHeartWin and @aantonop . Use what ever you can to get however much Bitcoin you can and hodl it till there is no more dollars backed by banks.
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Mis inversiones en Bitcoin van a la alza pic.twitter.com/oqW5OdkQhX
# 	Actual:  -3.130703337
# ------------------
# Text:
#  When all the dust settles and your kids are scared shitless, my kids will know how to remain calm, they can hunt, fish, farm, build a fire, repair shit thatâs broke, and defend themselves, while your kids will be trained to log into a Bitcoin account. Great job dad!
# 	Actual:  -3.130703337
# ------------------
# Text:
#  I've been using 2nd Layer solutions for 5 years like the @gyft card and/or the @xapo debit card. None of these imposed themselves on the blockchain by limiting its use case to a privilege settlement layer. #BCH is #Bitcoin . Teleportation" lol. http:// txhighway.com /"
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Absolutely agree. There have been numerous scam claim sites and malicious wallets for Bitcoin Diamond. Scammers are doing the rounds on Twitter and probably elsewhere. https:// twitter.com/ledgerhq/statu s/943915102780223495 â¦
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Probably about to invest some money in bitcoin
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Still Confused About Bitcoin ? https:// goo.gl/fb/NnX12g #currency
# 	Actual:  -3.130703337
# ------------------
# Text:
#  So we can safely predict Bitcoin Core will settle down to about $1200 and #BitcoinCash will top out at $1 million dollars.
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Vendo iPhone 7 32gb pouco tempo de uso $$ ou Bitcoin RT PRA AJUDAR
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Bitcoin , bubbles and tech. Here are Google's top finance searches for 2017 https:// bloom.bg/2kWmUcd pic.twitter.com/vGBuAp7jjj
# 	Actual:  -3.130703337
# ------------------
# Text:
#  send me loads of bitcoin and then ill give a small portion away. (Maybe)
# 	Actual:  -3.130703337
# ------------------
# Text:
#  A question Iâve heard more recently is what do I use alt coins for? My A: to acquire Bitcoin . Period. Let me say it again, to acquire $ BTC . Trade the pairs and ride the momo, then flip it back for your $ BTC - and now is a pretty good time to start doing that w alts! #Bitcoin
# 	Actual:  -3.130703337
# ------------------
# Text:
#  Ah, can you explain how a government can shut down all of bitcoin ?
# 	Actual:  -3.130703337
# ------------------
# Text:
#  NordVPN ermÃ¶glicht es Ihnen, gleichzeitig zu sechs GerÃ¤te anzuschlieÃen. In den meisten Gaming-Szenarien kann dies nicht erforderlich, wenn i Bitcoin kaufen kann. wenn Sie mehrere Spieler in Ihrem Hause haben jedoch, und eine ausreichende Bandbreite, dann ist es ei...
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Centralization can be avoided via chain splits. If Bitcoin base block size was too large now and some users agreed, they could create a fork w/ new PoW and smaller blocks. If market wanted this much censorship resistance, it would have users and a high price
# 	Actual:  -2.941902147
# ------------------
# Text:
#  What Else Should I Buy Besides Bitcoin ? https://www. learncryptoinvesting.com/else-buy-besid es-bitcoin/ â¦
# 	Actual:  -2.941902147
# ------------------
# Text:
#  South Korea: Five Local #Bitcoin Exchanges Fail Security Test, Hacked With âBasic Toolsâ http:// bit.ly/2l3O0xW via @Cointelegraph #cryptocurrency pic.twitter.com/qXR9bS4J23
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Smart Cannabis Corp and SinglePoint, Inc. Announce Joint Venture Expanding Blockchain Technology into SMARTAPP Automation Software for the Rapidly Growing Cannabis Market https:// bit-media.org/news/smart-can nabis-corp-and-singlepoint-inc-announce-joint-venture-expanding-blockchain-technology-into-smartapp-automation-software-for-the-rapidly-growing-cannabis-market/ â¦ #bitcoin #blockchain #coindesk #crypto #cryptocurrency #fintech
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Merry Christmas and my stocking accepts Canadian, US dollars and Euros but no BitCoin please
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Seems like Lightning network use case is now priced out of Bitcoin . How would you feel if you had to spend $50 every time you wanted to move money in and out of Paypal? Or even $10?
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Most outgoing transactions are from exchanges. Exchanges don't care about efficient transactions because they pass the costs onto the users and don't really want the users to take their money off anyway. Users must educate themselves and demand change from exchanges . #Bitcoin
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Christ alone can save us. Social conventions, cultural movements, Meghan Markle and Prince Harry, motivational speakers, inspirational leaders, bitcoin , politicians and political parties, meditation, vegan diets, the universe, wealth, fame ... cannot.
# 	Actual:  -2.941902147
# ------------------
# Text:
#  ãããã³ã¤ã³ãã¼ããã©ã¼ã¯æå ± â Bitcoin GODãã¼ããã©ã¼ã¯ äºå®æ¥: 2017å¹´12æ25æ¥ ãã­ãã¯æ°ï¼501225 çºè¡æ°ï¼21,000,000 ãã­ãã¯æ°ã501225ã®éã«ä¿æãã¦ããBTCæ°ã«å¯¾ãã¦ã1:1ã®å²åã§GODãçºè¡ããã¾ãã å¬å¼ãµã¤ãï¼è±èªï¼: https://www. bitcoingod.org #ãã¼ããã©ã¼ã¯ #bitcoingod
# 	Actual:  -2.941902147
# ------------------
# Text:
#  CRYPTO NEWS: What Comes After the Futures? The Next Chapter for Bitcoin http:// dlvr.it/Q7MltC HowToBuy BNB via â http:// bit.do/_BNB
# 	Actual:  -2.941902147
# ------------------
# Text:
#  CRYPTO NEWS: Bitcoin 's Price Recovery Continues Following Massive Slump http:// dlvr.it/Q7MlpH HowToBuy BNB via â http:// bit.do/_BNB
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Why are there different prices for Bitcoin in different websites? #bitcoin #tech #education #video #news @blockchaininfos #Oneblockchainatatime http:// youtube.com/watch?v=697H_X â¦ pic.twitter.com/PguOseu8JU
# 	Actual:  -2.941902147
# ------------------
# Text:
#  The threat is *not* imaginary. The corporate boogeyman" is *always* right around the corner, especially when large amounts of money are involved. The main problem Bitcoin set out to solve is unavoidable corruption inherent in centrally controlled money."
# 	Actual:  -2.941902147
# ------------------
# Text:
#  If there was no change in price for 3 weeks, would the bitcoin bashers still come out of the woodwork? #SALTY
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Bitcoin finds a floor after worst sell off since 2015 https://www. thenational.ae/business/techn ology/bitcoin-finds-a-floor-after-worst-sell-off-since-2015-1.689960 â¦ pic.twitter.com/qi0WzRtpQj
# 	Actual:  -2.941902147
# ------------------
# Text:
#  So many racist uncles are getting ready to ask you what a bitcoin is right now. Theyâre primed.
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Bitcoin Subscription Purchases Limited to Annual Plans Only : https:// blog.coinigy.com/2017/12/bitcoi n-subscription-purchases-limited-to-annual-plans-only/ â¦
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Overstock CEO Discusses Threat To Bitcoin Investors https:// btcmanager.com/overstock-ceo- discusses-threat-bitcoin-investors/ â¦
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Â¿ExplotÃ³ la burbuja?: el precio del Bitcoin llegÃ³ a caer casi un 40% en la semana y arrastrÃ³ a mÃ¡s de 90 criptomonedas" http:// m.iprofesional.com/notas/260804-b anco-central-inversiones-moneda-demanda-mercado-divisas-fondos-bitcoin-coindesk-chicago-board-options-exchange-chicago-mercantile-exchange-ripple-charlie-lee-litecoin-Exploto-la-burbuja-el-precio-del-Bitcoin-llego-a-caer-casi-un-40-en-la-semana-y-arrastro-a-mas-de-90-criptomonedas â¦"
# 	Actual:  -2.941902147
# ------------------
# Text:
#  call #bitcoin $ btc $ 9700
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Added bitcoin to my name but still havenât picked up any new followers.
# 	Actual:  -2.941902147
# ------------------
# Text:
#  El BCE âsigue de cercaâ el devenir del bitcoin , pero ni considera impulsarlo http://www. ticbeat.com/innovacion/el- bce-sigue-de-cerca-el-devenir-del-bitcoin-pero-ni-considera-impulsarlo/ â¦
# 	Actual:  -2.941902147
# ------------------
# Text:
#  Markets Right Now: Stocks End Slightly Lower on Wall Street https:// buff.ly/2l0YFJJ #bitcoin #cryptocurrency pic.twitter.com/LdQtyZeEtv
# 	Actual:  -2.941902147
# ------------------
# Text:
# ...
# 	Actual:  -7.042007168
# ------------------
# Text:
#  Why would a Bitcoin crash trigger a stock crash? I can't imagine a bunch of asset managers were long Bitcoin and are are selling stocks to make margin calls. https://www. motherjones.com/kevin-drum/201 8/02/bitcoin-stock-market-both-tumbling/ â¦
# 	Actual:  -7.042007168
# ------------------
# Text:
#  Bitcoin has a huge scaling problemâLightning could be the solution https:// arstechnica.com/?post_type=pos t&p=1240391 â¦ #iot #aws #cloud #data
# 	Actual:  -7.042007168
# ------------------
# Text:
#  âEl bitcÃ³in debe prohibirseâ, sugiere premio Nobel de EconomÃ­a https:// goo.gl/syvMDb
# 	Actual:  -7.042007168
# ------------------
# Text:
#  Shocking! Bitcoin price fell to pre CME futures news Calling this a bubble above the 17.5k doesn't make you giniuos, in fact almost every crypto player knew this was coming, some were just not ready for it or don't really give a fuck - they want to stay in the game no matter what
# 	Actual:  -7.042007168
# ------------------
# Text:
#  Discuss your ideas and questions with @SilverBitSLV team on our Telegram channel #crypto #BTC #LTC #cryptocurrency #Bitcoin https:// t.me/joinchat/HdLPM xIwClLUky46-5yu0g â¦
# 	Actual:  2.055772676
# ------------------
# Text:
#  $ btc #bitcoin pic.twitter.com/EzQb40L8UC
# 	Actual:  2.055772676
# ------------------
# Text:
#  I still cannot find a video of Roger on Infowars. Was it cancelled because the stuff Roger was saying just sound too" crazy for his show? #Bitcoin #BCash #BitcoinCash https:// twitter.com/rogerkver/stat us/960631467746439168 â¦"
# 	Actual:  2.055772676
# ------------------
# Text:
#  PSA: No India hasnât banned Bitcoin â but itâs still talking tough on crypto http:// dlvr.it/QFSXWB pic.twitter.com/GF2REFwk1o
# 	Actual:  2.055772676
# ------------------
# Text:
#  Retweet For A Chance To Win 0.01149441 $ BTC (Don't Forget To Comment Your #bitcoin Tip Address In This Post) Tags: $ Doge $ SC $ DGB $ XVG #Dogecoin #Siacoin #Digibyte #Verge $ rdd $ Btc $ xmy $ ltc $ vtc $ ppc $ ftc $ nxt $ dash $ pot $ blk $ aur $ efl $ gld $ fair $ slr $ ptc $ grs $ nlg $ rby $ xwc
# 	Actual:  2.055772676
# ------------------
# Text:
#  Gold is already disrupted, by fraud. #Bitcoin disrupts the disruption of gold.
# 	Actual:  2.055772676
# ------------------
# Text:
#  Why all the bitcoin promoted ads ? Am I missing something ?
# 	Actual:  2.055772676
# ------------------
# Text:
#  #wings coin NOW. BUY BUY !!!! http:// binance.com/?ref=13006762 #entrepreneurlife #bitcoin #bitcoinexchange #bitcointrade #bitcoins #bitcoinnews #bitcoinmining #bitcoinmillionaire #bitcoinprice #bitcointechnology #btc
# 	Actual:  2.055772676
# ------------------
# Text:
#  Sign Up Earn Free LGT http:// legt.me/226712 Launch your profit to space! #bitcoin #crypto #cryptocurrency #btc #ETH #blockchain #ico #altcoin #trading #blogging #bounty #reward #TokenSale #crowdsale #Tokens #business #finance #socialmedia #makemoney #social #market #social
# 	Actual:  2.055772676
# ------------------
# Text:
#  Jim is just a savy internet marketer. Being a #bitcoin villain is a great way to attract a ton of traffic, and maybe suck a few into his paid âadviceâ service.
# 	Actual:  2.055772676
# ------------------
# Text:
#  Another falsehood, fees are low right now. 1 satoshi/byte transactions are clearing in the mempool. 1 satoshi is the lowest unit of Bitcoin , in case you didn't know. https:// dedi.jochen-hoenicke.de/queue/more/#24h
# 	Actual:  2.055772676
# ------------------
# Text:
#  Don't beat yurself up next yr for not investing today! #bitcoin #CryptoCurrency #XVG #ADA #xlm #eth #Btc #trx #Investing #money
# 	Actual:  2.055772676
# ------------------
# Text:
#  $ MRNJ Japan's largest Electronics Retailer starts Taking Bitcoin ! Invest Reverse Proof Stock with Crypto Direct at http:// bit.ly/2ouXHWU #wsj #nytimes #reuters #bloomberg #thestreet #jimmyfallon #forbes #chicago #ihub #newyork #bitcoin #business #crypto #cnn #bet #foxnews pic.twitter.com/m8Hb3rxNqS
# 	Actual:  2.055772676
# ------------------
# Text:
#  #Bitcoin Price Watch; Low Volume Trading - @NEWSBTC #Crypto #Blockchain #BTC #CryptoTrading http:// rocktrader.eu/p/4091502417/2 017/12/28/bitcoin-price-watch-low-volume-trading-newsbtc-crypto-blockchain-btc-cryptotrading?utm_medium=social&utm_source=twitter â¦
# 	Actual:  2.055772676
# ------------------
# Text:
#  Cannabis Millionaire in 5 months. http://www. tree420.com . https:// uMail.link/CannabisFarms . #bitcoin #BitcoinToken #TokenSale #token #btc #Blockchain #crypto #Cryptocurrency #1DDrive #TrapaDrive #followme #investment #invest #Malaysia #SingaporeAirshow #Singapore #usa pic.twitter.com/VWMKFabMQA
# 	Actual:  2.055772676
# ------------------
# Text:
#  Bitcoin ve diÄer benzeri kripto paralar tabanda herkesin madencilik sayesinde para yaratmasÄ±na" izin vererek bu iÅi tabana yaydÄ±lar. Ethereum benzeri kripto paralar ise giriÅimcilere toplu para "yaratma" imkanÄ± sunarak bankalara olan ihtiyacÄ± tamamen kaldÄ±rdÄ±lar."
# 	Actual:  2.055772676
# ------------------
# Text:
#  Remember: as long as #BTC holds over $7300 to $7500, we should be fine. Don't panic either way. This was expected & predicted in an earlier tweet. $ BTC #Bitcoin
# 	Actual:  2.055772676
# ------------------
# Text:
#  Nailed it! So many cry foul immediately just because someone is building a for-profit company/business since for some reason they believe this to be evil. This is why I've previously said #socialists have infiltrated #bitcoin #btc and #libertarians have moved to #bitcoinCash #BCH
# 	Actual:  2.055772676
# ------------------
# Text:
#  Didn't you see? Bitcoin crashed, no money for actual food, just grass
# 	Actual:  2.055772676
# ------------------
# Text:
#  Is it just me, or does it really look like someone is trying to keep the #Bitcoin mempool from going to 0???? pic.twitter.com/sUN7iGJoo4
# 	Actual:  2.055772676
# ------------------
# Text:
#  What is Venezuelaâs Petro? Itâs socialism to bitcoin âs rescue" http://www. greanvillepost.com/2018/02/07/wha t-is-venezuelas-petro-its-socialism-to-bitcoins-rescue/ â¦ #headlines #noticias #news #nouvelles #notizia #ÐÐ¾Ð²Ð¾ÑÑÐ¸ #berita #news"
# 	Actual:  2.055772676
# ------------------
# Text:
#  Here are two guys saying #Bitcoin goes to $320,000 https://www. marketwatch.com/story/winklevo ss-if-you-cant-see-bitcoin-at-320000-you-just-lack-imagination-2018-02-07 â¦
# 	Actual:  2.055772676
# ------------------
# Text:
#  Today, you'd need 137 Bitcoins to become a Bitcoin Millionaire. Just 50 days ago, it was 50 Bitcoins.
# 	Actual:  2.055772676
# ------------------
# Text:
#  going to Hell in a Bucket bear cycle h" fractal $ btc $ bcc $ bch $ eth $ ltc bitcoin litecoin ethereum $ iota $ zec $ etc pic.twitter.com/60w4VjJIFE"
# 	Actual:  2.055772676
# ------------------
# Text:
#  Bitcoin drops a few percent after going up 40% in less then 2 days and everyone panics and starts calling for $5-$6k. Chill out people.
# 	Actual:  2.055772676
# ------------------
# Text:
#  New #Monero -Mining Malware Targets #Android #Devices , Thousands #Infected https:// cointelegraph.com/news/new-moner o-mining-malware-targets-android-devices-thousands-infected â¦ #Bitcoin #Ethereum #Blockchain #CryptoRegulations #BTC #CryptoNews #Ripple #Litecoin #markets #cryptocurrency #Crypto #news #Bitcoin #ICO #SEC #BitcoinsCorrection #Mining
# 	Actual:  2.055772676
# ------------------
# Text:
#  #Airdrop #Bitcoin #Blockchain #Bilibit #XRP #Cryptocurrencies #Ethereum Join Bilibit Airdrop To get 1500 BLB https:// goo.gl/DGFHn1 @Ajikudos2 @hitContinue @oktacrypto @angelaImarie @Karagodina_M
# 	Actual:  2.055772676
# ------------------
# Text:
#  In just the last 7 days, the US #StockMarket saw over $4 Trillion get wiped out - 11X the size of the entire #cryptocurrency marketcap! Needless to say, we're only just beginning! #Bitcoin $ BTC
# 	Actual:  2.055772676
# ------------------
# Text:
#  Listening to @ChrisHogan360 discuss @Bitcoin is educating. Bitcoin is a gamble, not an investment. #cryptocurrency
# 	Actual:  2.055772676
# ------------------
# Text:
#  #Crypto #Helbiz , #HBZ #ShareYourWheels #sharingeconomy #HBZCOIN #HelbizCoin#Blockchain #ICO #Crowdfunding #ethereum #TGE #cryptocurrency #Bitcoin #IBelieveInHelbiz #Ethereum https:// twitter.com/helbizofficial /status/960649598871199745 â¦
# 	Actual:  2.055772676
# ------------------
# Text:
#  wow @rogerkver , look at the hundred or so coins that have had greater returns than BCash in the last 6 months- maybe THEY are the real Bitcoin ?
# 	Actual:  2.055772676
# ------------------
# Text:
#  At the moment I dont see why goverments would crack down on IOTA since this tech is developed for machine to machine economy and the foundation seeks cooporation with banks and goverments. Althaugh i share your concerns of bitcoin I believe there are some good projects out there.
# 	Actual:  2.055772676
# ------------------
# Text:
#  #313 Latest Bitcoin Price is in USD : 7571.88$ in INR : 486190.49 Rs %age change since last update = -2.25% #Bitcoin #Crypto #Cryptocurrency
# 	Actual:  2.055772676
# ------------------
# Text:
#  Get new people to join Cibus Telegram group https:// medium.com/cibusworld/tel egram-referral-reward-2eab0b4531e6 â¦ â¦ #blockchain #Bitcoin #ICO #Ethereum #cryptocurrency #CIBUS
# 	Actual:  2.055772676
# ------------------
# Text:
#  Bitcoin drops below $6,000 for first time since November https:// goo.gl/xUssmv #bitcoin #bitconnect #wgcrypto #cloudmining #hashflare
# 	Actual:  2.055772676
# ------------------
# Text:
#  Investing in fads like Bitcoin or Marijuana stocks: Quack like a duck and you may get plucked http:// findependencehub.com/investing-fads -like-bitcoin-marijuana-stocks-quack-like-duck-may-get-plucked/ â¦
# 	Actual:  2.055772676
# ------------------
# Text:
#  Bitcoin To $50k, Overall Market Cap To $1 Trln In 2018 | Experts Predict http:// bit.ly/2FW4Szr
# 	Actual:  2.055772676
# ------------------
# Text:
#  #Zug - Im selbsternannten Crypto Valley ist die GoldgrÃ¤berstimmung zu Ende. https://www. nzz.ch/schweiz/die-bi tcoin-blase-platzt-im-zuger-crypto-valley-wachsen-die-bedenken-ld.1354992 â¦
# 	Actual:  3.283099458
# ------------------
# Text:
#  Face Popart 30x40 sell in #Kryptowaehrung #Cardano #Eth #ripple #Verge #thx #bitcoin Bei Interesse bitte PN Gratis Versand pic.twitter.com/SZXjKkjK38
# 	Actual:  -2.9081929210000004
# ------------------
# Text:
#  Kein Staat kann Bitcoin stoppen" https://www. sn.at/wirtschaft/wel t/kein-staat-kann-bitcoin-stoppen-24026590 â¦ via @sn_aktuell pic.twitter.com/EtsoSVqY7O"
# 	Actual:  -2.9081929210000004
# ------------------
# Text:
#  Retweets keep us Alive! Love you. #Bitcoin #Blockchain #cryptocurrency #crypto #money BINANCE EinfÃ¼hrung | KryptowÃ¤hrungen einfach erklÃ¤rt! http:// flavorfam.com/2018/02/10/bin ance-einfuhrung-kryptowahrungen-einfach-erklart/ â¦ pic.twitter.com/mBk2XjgvWH
# 	Actual:  -2.9081929210000004
# ------------------
# Text:
#  WachablÃ¶se im Dark Web: Cyberkriminelle wechseln von #Bitcoin zu #Litecoin und#Dash https:// buff.ly/2EgQvFN pic.twitter.com/m3TXXYRWUu
# 	Actual:  -2.998594065
# ------------------
# Text:
#  Altcoin Analysis: NEO, EOS, LTC, NEM and Lumens http:// dlvr.it/QFpVjB #Bitcoin pic.twitter.com/EJVftmOYAg
# 	Actual:  -2.998594065
# ------------------
# Text:
#  Rabatte fÃ¼r #iOS und #macOS : Spiele, #Bitcoin -Ticker, Periodensystem und mehr im #Angebot https://www. apfelpage.de/news/rabatte-f uer-ios-und-macos-spiele-bitcoin-ticker-periodensystem-und-mehr-im-angebot/ â¦ pic.twitter.com/wcbnL3c18N
# 	Actual:  -2.998594065
# ------------------
# Text:
#  Kleine Terminerinnerung: Heute findet die Bitcoin Private Konferenz in New York statt. Livestream-Link folgt! $ BTCP #BTCP #BitcoinPrivate #BTCPGermany #BTCPNY #BTCPnewyork $ ZCL $ZClassic $ BTC #BTC
# 	Actual:  -2.998594065
# ------------------
# Text:
#  EIn neuer #Venom Trailer, der #Bitcoin fÃ¤hrt Achterbahn, #SeaofThieves bekommt eine Open Beta und #MonsterHunterWorld bekommt ein neues Update. Das und noch mehr erfahrt Ihr inn den #News ! #youtube #xbox #ps4 #gaming #trending #pubg #samstag #gamingnews https:// youtu.be/gKMBbE_PpUk
# 	Actual:  -2.998594065
# ------------------
# Text:
#  Blockchain und Bitcoin : Was muss ich wissen? Jetzt kostenlos an unserem Event am 21. MÃ¤rz in Winterthur teilnehmen: https:// startups.ch/de/vorbereiten /kursbesuch/startups-academy/blockchain-und-bitcoin/ â¦ @STARTUPSCH #blockchain #bitcoin #KNOWLEDGE #renuo pic.twitter.com/meGEeXm1ro
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Join aelf in die deutsche telegram gruppe, es gibt ein nettes candyprogramm fÃ¼r jeden der bisschen tweetet oder liked, sprich free aelf token fÃ¼r jeden! https:// t.me/aelfgerman #Kryptowaehrung #Kryptowaehrungen #KryptowÃ¤hrung #bitcoin #btc #krypto #germanblockchaincommunity #aelf pic.twitter.com/lku4Hbpsan
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Wer heute das, was er nicht hat, in Bitcoins investiert, sollte sich morgen nicht Ã¼ber Altersarmut beschweren. #Bitcoin
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Bitcoin -Crash auf 1000 Dollar? Experte nennt den Zeitpunkt https:// sptnkne.ws/gG6U pic.twitter.com/eiYIPQmZDo
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Das Internet wird sich nicht durchsetzen und Bitcoin ist nur eine Blase.. pic.twitter.com/opcPGJro01
# 	Actual:  -2.735294614
# ------------------
# Text:
#  http:// bit.ly/2nPBSTG - Die 10 beliebtesten Artikel der Woche: iPhone-Verkaufsverbot wird verhandelt und Bitcoin -KriegserklÃ¤rung - http:// wig.li/YNNlN pic.twitter.com/MGei3sMoB7
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Ich mag das @YouTube -Video: http:// youtu.be/UbqecKr-2c0?a Bitcoin | Rick and Morty
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Dafuq is bitcoin heist :D
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Warum Bitcoin schlecht fÃ¼r die Umwelt ist https://www. youtube.com/watch?v=0eTRK- 8o0hA â¦
# 	Actual:  -2.735294614
# ------------------
# Text:
#  Im Radio: Ich geh als #Bitcoin zum Fasching, damit ich richtig abstÃ¼rzen kann.""
# 	Actual:  2.09809662
# ------------------
# Text:
#  Bitcoin discussies met Erik pic.twitter.com/iyrzGk6p57
# 	Actual:  2.09809662
# ------------------
# Text:
#  News: Bitcoin -Mining per Supercomputer - Russische Nuklear-Physiker verhaftet http:// dlvr.it/QFv5C2 pic.twitter.com/d8s4Sh3oiU
# 	Actual:  2.09809662
# ------------------
# Text:
#  #Digitalisierung gehÃ¶rt ganz oben auf die politische #Tagesordnung #GroKo #industrie40 #Blockchain #Bitcoin #Cloud #KI Lesen Sie hier: https:// bielmeiersblog.dzbank.de/wp-content/upl oads/2018/02/BielmeiersWelt_Digitalisierung-geh%C3%B6rt-ganz-oben-auf-die-politische-Tagesordnung.pdf â¦ pic.twitter.com/eqz2D1ukeA
# 	Actual:  2.09809662
# ------------------
# Text:
#  Altcoin Analysis: NEO, EOS, LTC, NEM and Lumens http:// tribetica.com/index.php/2018 /02/07/altcoin-analysis-neo-eos-ltc-nem-and-lumens/ â¦ #newsoftheweek #Bitcoin #blockchain #crypto #cryptocurrency #news pic.twitter.com/WcnlOHB1Fk
# 	Actual:  2.555563545
# ------------------
# Text:
#  EOS Market Report: $ EOS Falls -11.28% as Bitcoin Drops http:// dlvr.it/QFtcrC pic.twitter.com/1KkSQTQqWE
# 	Actual:  2.555563545
# ------------------
# Text:
#  #Digitalisierung gehÃ¶rt ganz oben auf die politische #Tagesordnung #Digitalminister #GroKo #industrie40 #Blockchain #Bitcoin #Cloud #KI Lesen Sie hier: https:// bielmeiersblog.dzbank.de/wp-content/upl oads/2018/02/BielmeiersWelt_Digitalisierung-geh%C3%B6rt-ganz-oben-auf-die-politische-Tagesordnung.pdf â¦ â¦ pic.twitter.com/5J9D7Cvc5m
# 	Actual:  2.7330541680000002
# ------------------
# Text:
#  Krypto-Hochburg SÃ¼dkorea plant strenge Regulierung des Handels mit digitalen WÃ¤hrungen. #bitcoin https://www. gruenderszene.de/allgemein/sued korea-strenge-regulierung-krypto â¦ pic.twitter.com/FWSfnLw2iq
# 	Actual:  2.7330541680000002
# ------------------
# Text:
#  Falls sich jemand fÃ¼r kleinere KryptowÃ¤hrungen interessiert, hier kommt ein Lesetipp. #gulden #nlg #Kryptowaehrung #bitcoin #ned https:// twitter.com/GuldenBites/st atus/963719597856784384 â¦
# 	Actual:  2.7330541680000002
# ------------------
# Text:
#  Alles zum Thema #Bitcoin und #blockchain heute um 19 Uhr in der pflugstraÃe 9a https:// berlin.piratenpartei.de
# 	Actual:  2.7330541680000002
# ----------------------
# Count of examples greater than cutoff: 544

# %% [markdown]
# ### Now print out the text corresponding to predictions greater than the cutoff

# %%
count = 0

for i, pred in enumerate(preds_list):
    if abs(pred) >= cutoff:
        print('------------------')
        print('Text:\n {}'.format(test_text[i]))
        print('\tPrediction: {}'.format(pred))
        print('\tActual:  {}'.format(labels_list[i]))
        count += 1

print("----------------------")
print("Count of examples greater than cutoff: {}".format(count))
# Out:
# ------------------
# Text:
#  #Bitcoin skeptic: It's gonna crash." Me: Yep - can't wait! #buythedip #Crypto #BTC"
# 	Prediction: 2.3728368282318115
# 	Actual:  0.021404632000000003
# ------------------
# Text:
#  #Blockchain Explained in 30 seconds#Fintech #Startups #innovation #Bitcoin #IoT #BigData #digital #disruption #Tech #cryptocurrency #infosec #CyberSecurity
# 	Prediction: 2.167842149734497
# 	Actual:  0.087557604
# ------------------
# Text:
#  XBS Airdrop Phase 1 is now live #bitcoin #xbs #btc #airdrop @airdrop_free @hamza_znad @bousnate @byzran @BTCX_Official @BitcoinNitro https:// docs.google.com/forms/d/e/1FAI pQLScONYqAAO5L6cLBt6lK_1B5Vr56wh5Mkot7NOOmmaZsH1B9cw/viewform â¦
# 	Prediction: 3.034097671508789
# 	Actual:  -1.4271542519999998
# ------------------
# Text:
#  Lol. No I wish, I just find Bcashâs takeover of the Bitcoin handle despicable. Iâll come up with some new trolling materials this weekend tho haha
# 	Prediction: 2.386861562728882
# 	Actual:  0.165271169
# ------------------
# Text:
#  #Vitrocoin #Airdrop #ETH #Freetoken #bitcoin #airdrops https:// docs.google.com/forms/d/e/1FAI pQLSd7urAdldjpLjsw6RnTEBhjPmmzm7UGW4UHLrps3gjw_-nUiA/viewform â¦
# 	Prediction: 2.4670228958129883
# 	Actual:  -0.257725321
# ------------------
# Text:
#  Auf Island werden die Bitcoin -Miner 2018 voraussichtlich mehr Strom verbrauchen als alle Privathaushalte zusammen (HS Orkas, BBC) @welt
# 	Prediction: 2.009453773498535
# 	Actual:  1.9450998119999998
# ----------------------
# Count of examples greater than cutoff: 6
